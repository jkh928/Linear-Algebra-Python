# %% [markdown]
# ## Vector Hadamard Mulitiplication

# %%
import numpy as np

# %% [markdown]
# #### Known as element-wise multiplication

# %%
# create vectors
v1 = [1, 3, 5]
v2 = [3, 4, 2]

# apply hadamard multiplication using multiply function
v3 = np.multiply(v1, v2)
print(v3)
# Out:
# [ 3 12 10]
